# %%
# !pip install ipython-sql psycopg2-binary
# Out:
# Requirement already satisfied: ipython-sql in c:\users\gebruiker\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: psycopg2-binary in c:\users\gebruiker\anaconda3\lib\site-packages (2.9.12)
# Requirement already satisfied: prettytable in c:\users\gebruiker\appdata\roaming\python\python312\site-packages (from ipython-sql) (3.5.0)
# Requirement already satisfied: ipython in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython-sql) (8.27.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython-sql) (2.0.50)
# Requirement already satisfied: sqlparse in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython-sql) (0.5.5)
# Requirement already satisfied: six in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in c:\users\gebruiker\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.5.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\gebruiker\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.15.0)
# Requirement already satisfied: decorator in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.3.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.20.0)
# Requirement already satisfied: stack-data in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.15.0)
# Requirement already satisfied: colorama in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\gebruiker\anaconda3\lib\site-packages (from prettytable->ipython-sql) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\gebruiker\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.7)
# Requirement already satisfied: executing>=1.2.0 in c:\users\gebruiker\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\gebruiker\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\gebruiker\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.3)
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\Gebruiker\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\Gebruiker\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~harset-normalizer (C:\Users\Gebruiker\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\Gebruiker\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~harset-normalizer (C:\Users\Gebruiker\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~harset-normalizer (C:\Users\Gebruiker\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\Gebruiker\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\Gebruiker\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\Gebruiker\AppData\Roaming\Python\Python312\site-packages)

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
from getpass import getpass
password = getpass("PostgreSQL password: ")
# Out:
# PostgreSQL password:  ········

# %%
import psycopg2

conn = psycopg2.connect(
    dbname="postgres",
    user="postgres",
    password=password,
    host="localhost",
    port="5432"
)

print("Connected!")
# Out:
# Connected!
